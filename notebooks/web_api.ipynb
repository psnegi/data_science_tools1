# %% [markdown]
# # What is REST API and why to use api?
#
# [REST](https://www.ics.uci.edu/~fielding/pubs/dissertation/rest_arch_style.htm): **Representational State Transfer**
#
# - Architectural style for communication often used in Web service development.
# - Uses a stateless operation in client server protocol to manipulate  server resources(image, blog etc.) in the web.
#
# When using [http](https://www.ietf.org/rfc/rfc2616.txt)/https most common available operations are

# %% [markdown]
# **GET**: To get the data from server
#
# **POST**: To submit data
#
# **PUT**: to update a resource
#
# **DELETE**: delete the resource
#
#
# Response will have a payload formatted in HTML, XML, **JSON**, or some other format.

# %% [markdown]
# # JSON (Java Script object notation)
# json is primary format used for data exchange. python has json library. we can use it to convert python object to string(**dumps method**) and  vice -versa **loads method**.

# %% [markdown]
# # Status code for GET request
# - 200: success
# - 400: bad request
# - 401: authentication failure
# - 404: resouce not found. Like wrong endpoint

# %% [markdown]
# Client applications use URI/URL to access RESTFUL web services.
#
# REST API has __*base url + endpoint+ parameters*__
#
# e.g - https://api.github.com/users
#     - https://api.github.com/users/user_id/repos

# %% [markdown]
# **Before using python Requests module, let's use curl to see rest API in action**
#
# Using github developer API we can get list of users as

# %%
# !curl https://api.github.com/users

# %% [markdown]
# # [Requests: HTTP for Humans](http://docs.python-requests.org/en/master/)
#
# From the website
#
# **"*Requests allows you to send organic, grass-fed HTTP/1.1 requests, without the need for manual labor.*"**
#
# Let's try to get NASA data using web API

# %%
import requests

# %% [markdown]
# ## APOD( Astronomy Picture of the Day)
# For passing parameters to the API using python dictionary

# %%
parameters = {"api_key":"DEMO_KEY"}
response = requests.get("https://api.nasa.gov/planetary/apod", params=parameters)

# %%
print(response.status_code)

# %% [markdown]
# Codes are available as

# %%
requests.codes.ok

# %%
response.headers

# %%
response.text

# %%
json_data = response.json()
type(json_data)

# %%
#!pip install pillow

# %%
from PIL import Image
from io import BytesIO
response = requests.get(json_data['url'])
img = Image.open(BytesIO(response.content))

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(14, 14))
ax.imshow(img)

# %% [markdown]
# ## Mars rovers photo

# %%
parameters = {"api_key":"DEMO_KEY", "sol":1000, "camera":"fhaz"}
api_end_point= "https://api.nasa.gov/mars-photos/api/v1/rovers/curiosity/photos"
response = requests.get(api_end_point, params=parameters)
response.status_code

# %%
json_data = response.json()
json_data

# %%
for image_data in json_data['photos']:
    response = requests.get(image_data['img_src'])
    fig, ax = plt.subplots(figsize=(14, 14))
    img = Image.open(BytesIO(response.content))
    ax.imshow(img)

# %% [markdown]
# # Twitter example with POST and GET

# %% [markdown]
# 1. create new app at https://apps.twitter.com/app/new
# 1. [twitter api reference index](https://developer.twitter.com/en/docs/api-reference-index)

# %% [markdown]
# # POST oauth2/token
# Allows a registered application to obtain an OAuth 2 Bearer Token, which can be used to make API requests on an application's own behalf, without a user context.
# https://developer.twitter.com/en/docs/basics/authentication/api-reference/token

# %%
client_key = 'cMAKpOIAiLXtsYsvYHSyy4ISJ'
client_secret = 'sqH2RBkSrX4I0GmqGb7uLAausxHVaUg86umAIyQ4fjPtwF4bmR'

# %%
import base64

key_secret = '{}:{}'.format(client_key, client_secret).encode('ascii')
b64_encoded_key = base64.b64encode(key_secret)
b64_encoded_key = b64_encoded_key.decode('ascii')

# %%
base_url = 'https://api.twitter.com/'
auth_endpoint = base_url+'oauth2/token'

auth_headers = { 'Authorization': 'Basic {}'.format(b64_encoded_key),
                'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8'}

auth_data = { 'grant_type': 'client_credentials'}

# %% [markdown]
# Let's post to authentication endpoint and get the token to be used in subsequent REST API call

# %%
response = requests.post(auth_endpoint, headers=auth_headers, data=auth_data)
response.status_code
# Out:
# 200

# %%
json_data =  response.json()
json_data
# Out:
# {'access_token': 'AAAAAAAAAAAAAAAAAAAAAEGe9QAAAAAALnCjfdkTP%2FJGQxEZOPTqGQL7jUs%3DTVrscEzlzvKPhNerXde7Btkx2aJ2TYtpuCpaHC3TwRfIKnX4vL',
#  'token_type': 'bearer'}

# %%
access_token = json_data['access_token']

# %% [markdown]
# # Let's do some search on climate change
# This is how we got search endpoint
#
# https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets

# %%
search_headers = {'Authorization': 'Bearer {}'.format(access_token)    
}

parameters = { 'q': 'climate change',
                    'result_type': 'recent',
                'count': 5 }

search_url = base_url+'1.1/search/tweets.json'

response = requests.get(search_url, headers=search_headers, params=parameters)

# %%
json_tweet_data = response.json()

# %%
import pprint

# %%
pprint.pprint(json_tweet_data)
# Out:
# {'search_metadata': {'completed_in': 0.029,
#                      'count': 5,
#                      'max_id': 1094034863525515264,
#                      'max_id_str': '1094034863525515264',
#                      'next_results': '?max_id=1094034851148099583&q=climate%20change&count=5&include_entities=1&result_type=recent',
#                      'query': 'climate+change',
#                      'refresh_url': '?since_id=1094034863525515264&q=climate%20change&result_type=recent&include_entities=1',
#                      'since_id': 0,
#                      'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#                'coordinates': None,
#                'created_at': 'Sat Feb 09 00:46:52 +0000 2019',
#                'entities': {'hashtags': [],
#                             'symbols': [],
#                             'urls': [],
#                             'user_mentions': [{'id': 81741855,
#                                                'id_str': '81741855',
#                                                'indices': [3, 19],
#                                                'name': 'Steven Beschloss',
#                                                'screen_name': 'StevenBeschloss'}]},
#                'favorite_count': 0,
#                'favorited': False,
#                'geo': None,
#                'id': 1094034863525515264,
#                'id_str': '1094034863525515264',
#                'in_reply_to_screen_name': None,
#                'in_reply_to_status_id': None,
#                'in_reply_to_status_id_str': None,
#                'in_reply_to_user_id': None,
#                'in_reply_to_user_id_str': None,
#                'is_quote_status': False,
#                'lang': 'en',
#                'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#                'place': None,
#                'retweet_count': 21,
#                'retweeted': False,
#                'retweeted_status': {'contributors': None,
#                                     'coordinates': None,
#                                     'created_at': 'Sat Feb 09 00:38:22 +0000 '
#                                                   '2019',
#                                     'entities': {'hashtags': [],
#                                                  'symbols': [],
#                                                  'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                                                            'expanded_url': 'https://twitter.com/i/web/status/1094032725118349313',
#                                                            'indices': [116,
#                                                                        139],
#                                                            'url': 'https://t.co/CGkPrqder0'}],
#                                                  'user_mentions': []},
#                                     'favorite_count': 83,
#                                     'favorited': False,
#                                     'geo': None,
#                                     'id': 1094032725118349313,
#                                     'id_str': '1094032725118349313',
#                                     'in_reply_to_screen_name': None,
#                                     'in_reply_to_status_id': None,
#                                     'in_reply_to_status_id_str': None,
#                                     'in_reply_to_user_id': None,
#                                     'in_reply_to_user_id_str': None,
#                                     'is_quote_status': False,
#                                     'lang': 'en',
#                                     'metadata': {'iso_language_code': 'en',
#                                                  'result_type': 'recent'},
#                                     'place': None,
#                                     'retweet_count': 21,
#                                     'retweeted': False,
#                                     'source': '<a '
#                                               'href="http://twitter.com/download/iphone" '
#                                               'rel="nofollow">Twitter for '
#                                               'iPhone</a>',
#                                     'text': 'At a time of great challenge, '
#                                             'from climate change to gun '
#                                             'violence to income equality, what '
#                                             'a waste of time dealing… '
#                                             'https://t.co/CGkPrqder0',
#                                     'truncated': True,
#                                     'user': {'contributors_enabled': False,
#                                              'created_at': 'Mon Oct 12 '
#                                                            '02:32:33 +0000 '
#                                                            '2009',
#                                              'default_profile': False,
#                                              'default_profile_image': False,
#                                              'description': 'Writer, '
#                                                             'journalist, '
#                                                             'filmmaker. Author '
#                                                             'of Oswald #book '
#                                                             'Gunman and His '
#                                                             'Mother: '
#                                                             'https://t.co/xfKaxoPQhQ. '
#                                                             'Passion for smart '
#                                                             'ideas, worthy '
#                                                             'tries, good '
#                                                             '#writing.',
#                                              'entities': {'description': {'urls': [{'display_url': 'amzn.to/2DckiyD',
#                                                                                     'expanded_url': 'http://amzn.to/2DckiyD',
#                                                                                     'indices': [77,
#                                                                                                 100],
#                                                                                     'url': 'https://t.co/xfKaxoPQhQ'}]},
#                                                           'url': {'urls': [{'display_url': 'stevenbeschloss.com',
#                                                                             'expanded_url': 'http://www.stevenbeschloss.com',
#                                                                             'indices': [0,
#                                                                                         23],
#                                                                             'url': 'https://t.co/8YHlAOg6W2'}]}},
#                                              'favourites_count': 18283,
#                                              'follow_request_sent': None,
#                                              'followers_count': 47833,
#                                              'following': None,
#                                              'friends_count': 889,
#                                              'geo_enabled': False,
#                                              'has_extended_profile': True,
#                                              'id': 81741855,
#                                              'id_str': '81741855',
#                                              'is_translation_enabled': False,
#                                              'is_translator': False,
#                                              'lang': 'en',
#                                              'listed_count': 343,
#                                              'location': '',
#                                              'name': 'Steven Beschloss',
#                                              'notifications': None,
#                                              'profile_background_color': '000000',
#                                              'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                                              'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                                              'profile_background_tile': False,
#                                              'profile_banner_url': 'https://pbs.twimg.com/profile_banners/81741855/1532182350',
#                                              'profile_image_url': 'http://pbs.twimg.com/profile_images/468989921/_DSC0662_-_CU_crop_-_Copy_normal.JPG',
#                                              'profile_image_url_https': 'https://pbs.twimg.com/profile_images/468989921/_DSC0662_-_CU_crop_-_Copy_normal.JPG',
#                                              'profile_link_color': '1B95E0',
#                                              'profile_sidebar_border_color': '000000',
#                                              'profile_sidebar_fill_color': '000000',
#                                              'profile_text_color': '000000',
#                                              'profile_use_background_image': False,
#                                              'protected': False,
#                                              'screen_name': 'StevenBeschloss',
#                                              'statuses_count': 24490,
#                                              'time_zone': None,
#                                              'translator_type': 'none',
#                                              'url': 'https://t.co/8YHlAOg6W2',
#                                              'utc_offset': None,
#                                              'verified': False}},
#                'source': '<a href="http://twitter.com/download/iphone" '
#                          'rel="nofollow">Twitter for iPhone</a>',
#                'text': 'RT @StevenBeschloss: At a time of great challenge, '
#                        'from climate change to gun violence to income '
#                        'equality, what a waste of time dealing w/T…',
#                'truncated': False,
#                'user': {'contributors_enabled': False,
#                         'created_at': 'Mon Feb 01 05:07:14 +0000 2010',
#                         'default_profile': True,
#                         'default_profile_image': False,
#                         'description': '”Son of a Son of a Sailor“Chileno 🇨🇱 '
#                                        '/USA',
#                         'entities': {'description': {'urls': []}},
#                         'favourites_count': 14375,
#                         'follow_request_sent': None,
#                         'followers_count': 195,
#                         'following': None,
#                         'friends_count': 405,
#                         'geo_enabled': False,
#                         'has_extended_profile': True,
#                         'id': 110332839,
#                         'id_str': '110332839',
#                         'is_translation_enabled': False,
#                         'is_translator': False,
#                         'lang': 'en',
#                         'listed_count': 9,
#                         'location': 'Santa Rosa California',
#                         'name': 'Robert Eastman',
#                         'notifications': None,
#                         'profile_background_color': 'C0DEED',
#                         'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                         'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                         'profile_background_tile': False,
#                         'profile_banner_url': 'https://pbs.twimg.com/profile_banners/110332839/1503534819',
#                         'profile_image_url': 'http://pbs.twimg.com/profile_images/1070127563731742721/SuDIiM7r_normal.jpg',
#                         'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1070127563731742721/SuDIiM7r_normal.jpg',
#                         'profile_link_color': '1DA1F2',
#                         'profile_sidebar_border_color': 'C0DEED',
#                         'profile_sidebar_fill_color': 'DDEEF6',
#                         'profile_text_color': '333333',
#                         'profile_use_background_image': True,
#                         'protected': False,
#                         'screen_name': 'bobbyoffshore',
#                         'statuses_count': 33561,
#                         'time_zone': None,
#                         'translator_type': 'none',
#                         'url': None,
#                         'utc_offset': None,
#                         'verified': False}},
#               {'contributors': None,
#                'coordinates': None,
#                'created_at': 'Sat Feb 09 00:46:51 +0000 2019',
#                'entities': {'hashtags': [],
#                             'symbols': [],
#                             'urls': [],
#                             'user_mentions': [{'id': 29442313,
#                                                'id_str': '29442313',
#                                                'indices': [3, 14],
#                                                'name': 'Bernie Sanders',
#                                                'screen_name': 'SenSanders'}]},
#                'favorite_count': 0,
#                'favorited': False,
#                'geo': None,
#                'id': 1094034858555322368,
#                'id_str': '1094034858555322368',
#                'in_reply_to_screen_name': None,
#                'in_reply_to_status_id': None,
#                'in_reply_to_status_id_str': None,
#                'in_reply_to_user_id': None,
#                'in_reply_to_user_id_str': None,
#                'is_quote_status': False,
#                'lang': 'en',
#                'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#                'place': None,
#                'retweet_count': 2444,
#                'retweeted': False,
#                'retweeted_status': {'contributors': None,
#                                     'coordinates': None,
#                                     'created_at': 'Fri Feb 08 18:30:54 +0000 '
#                                                   '2019',
#                                     'entities': {'hashtags': [],
#                                                  'symbols': [],
#                                                  'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                                                            'expanded_url': 'https://twitter.com/i/web/status/1093940249754042368',
#                                                            'indices': [117,
#                                                                        140],
#                                                            'url': 'https://t.co/w3zmWb1Ajy'}],
#                                                  'user_mentions': []},
#                                     'favorite_count': 10114,
#                                     'favorited': False,
#                                     'geo': None,
#                                     'id': 1093940249754042368,
#                                     'id_str': '1093940249754042368',
#                                     'in_reply_to_screen_name': None,
#                                     'in_reply_to_status_id': None,
#                                     'in_reply_to_status_id_str': None,
#                                     'in_reply_to_user_id': None,
#                                     'in_reply_to_user_id_str': None,
#                                     'is_quote_status': False,
#                                     'lang': 'en',
#                                     'metadata': {'iso_language_code': 'en',
#                                                  'result_type': 'recent'},
#                                     'place': None,
#                                     'possibly_sensitive': False,
#                                     'retweet_count': 2444,
#                                     'retweeted': False,
#                                     'source': '<a '
#                                               'href="https://studio.twitter.com" '
#                                               'rel="nofollow">Twitter Media '
#                                               'Studio</a>',
#                                     'text': 'I am proud to be an original '
#                                             'co-sponsor of the Green New Deal '
#                                             'proposal. We must address the '
#                                             'existential crisis of p… '
#                                             'https://t.co/w3zmWb1Ajy',
#                                     'truncated': True,
#                                     'user': {'contributors_enabled': False,
#                                              'created_at': 'Tue Apr 07 '
#                                                            '13:02:35 +0000 '
#                                                            '2009',
#                                              'default_profile': False,
#                                              'default_profile_image': False,
#                                              'description': 'U.S. Senator '
#                                                             'Bernie Sanders of '
#                                                             'Vermont is the '
#                                                             'longest-serving '
#                                                             'independent in '
#                                                             'congressional '
#                                                             'history.',
#                                              'entities': {'description': {'urls': []},
#                                                           'url': {'urls': [{'display_url': 'sanders.senate.gov',
#                                                                             'expanded_url': 'http://www.sanders.senate.gov/',
#                                                                             'indices': [0,
#                                                                                         22],
#                                                                             'url': 'http://t.co/8AS4FI1oge'}]}},
#                                              'favourites_count': 44,
#                                              'follow_request_sent': None,
#                                              'followers_count': 8106235,
#                                              'following': None,
#                                              'friends_count': 2095,
#                                              'geo_enabled': True,
#                                              'has_extended_profile': True,
#                                              'id': 29442313,
#                                              'id_str': '29442313',
#                                              'is_translation_enabled': False,
#                                              'is_translator': False,
#                                              'lang': 'en',
#                                              'listed_count': 26037,
#                                              'location': 'Vermont/DC',
#                                              'name': 'Bernie Sanders',
#                                              'notifications': None,
#                                              'profile_background_color': '000000',
#                                              'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                                              'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                                              'profile_background_tile': False,
#                                              'profile_banner_url': 'https://pbs.twimg.com/profile_banners/29442313/1430854323',
#                                              'profile_image_url': 'http://pbs.twimg.com/profile_images/794619281271033856/Fs0QQaH7_normal.jpg',
#                                              'profile_image_url_https': 'https://pbs.twimg.com/profile_images/794619281271033856/Fs0QQaH7_normal.jpg',
#                                              'profile_link_color': '03102D',
#                                              'profile_sidebar_border_color': 'FFFFFF',
#                                              'profile_sidebar_fill_color': 'D6CCB6',
#                                              'profile_text_color': '304562',
#                                              'profile_use_background_image': True,
#                                              'protected': False,
#                                              'screen_name': 'SenSanders',
#                                              'statuses_count': 19891,
#                                              'time_zone': None,
#                                              'translator_type': 'none',
#                                              'url': 'http://t.co/8AS4FI1oge',
#                                              'utc_offset': None,
#                                              'verified': True}},
#                'source': '<a href="http://twitter.com/download/iphone" '
#                          'rel="nofollow">Twitter for iPhone</a>',
#                'text': 'RT @SenSanders: I am proud to be an original '
#                        'co-sponsor of the Green New Deal proposal. We must '
#                        'address the existential crisis of planetary…',
#                'truncated': False,
#                'user': {'contributors_enabled': False,
#                         'created_at': 'Thu Nov 28 02:51:40 +0000 2013',
#                         'default_profile': True,
#                         'default_profile_image': False,
#                         'description': 'maniac',
#                         'entities': {'description': {'urls': []}},
#                         'favourites_count': 6268,
#                         'follow_request_sent': None,
#                         'followers_count': 79,
#                         'following': None,
#                         'friends_count': 239,
#                         'geo_enabled': True,
#                         'has_extended_profile': False,
#                         'id': 2218777842,
#                         'id_str': '2218777842',
#                         'is_translation_enabled': False,
#                         'is_translator': False,
#                         'lang': 'en',
#                         'listed_count': 10,
#                         'location': '',
#                         'name': 'Sarah Wagstaff',
#                         'notifications': None,
#                         'profile_background_color': 'C0DEED',
#                         'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                         'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                         'profile_background_tile': False,
#                         'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000800121021/707ae51e5f7c46ee4d466492ebb2e241_normal.jpeg',
#                         'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000800121021/707ae51e5f7c46ee4d466492ebb2e241_normal.jpeg',
#                         'profile_link_color': '1DA1F2',
#                         'profile_sidebar_border_color': 'C0DEED',
#                         'profile_sidebar_fill_color': 'DDEEF6',
#                         'profile_text_color': '333333',
#                         'profile_use_background_image': True,
#                         'protected': False,
#                         'screen_name': 'RedLitMischief',
#                         'statuses_count': 2467,
#                         'time_zone': None,
#                         'translator_type': 'none',
#                         'url': None,
#                         'utc_offset': None,
#                         'verified': False}},
#               {'contributors': None,
#                'coordinates': None,
#                'created_at': 'Sat Feb 09 00:46:51 +0000 2019',
#                'entities': {'hashtags': [],
#                             'symbols': [],
#                             'urls': [],
#                             'user_mentions': [{'id': 47747074,
#                                                'id_str': '47747074',
#                                                'indices': [3, 15],
#                                                'name': 'Brian Schatz',
#                                                'screen_name': 'brianschatz'}]},
#                'favorite_count': 0,
#                'favorited': False,
#                'geo': None,
#                'id': 1094034858513440768,
#                'id_str': '1094034858513440768',
#                'in_reply_to_screen_name': None,
#                'in_reply_to_status_id': None,
#                'in_reply_to_status_id_str': None,
#                'in_reply_to_user_id': None,
#                'in_reply_to_user_id_str': None,
#                'is_quote_status': False,
#                'lang': 'en',
#                'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#                'place': None,
#                'retweet_count': 4644,
#                'retweeted': False,
#                'retweeted_status': {'contributors': None,
#                                     'coordinates': None,
#                                     'created_at': 'Fri Feb 08 16:12:46 +0000 '
#                                                   '2019',
#                                     'entities': {'hashtags': [],
#                                                  'symbols': [],
#                                                  'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                                                            'expanded_url': 'https://twitter.com/i/web/status/1093905487278465025',
#                                                            'indices': [116,
#                                                                        139],
#                                                            'url': 'https://t.co/OHxUjzjzHB'}],
#                                                  'user_mentions': []},
#                                     'favorite_count': 25180,
#                                     'favorited': False,
#                                     'geo': None,
#                                     'id': 1093905487278465025,
#                                     'id_str': '1093905487278465025',
#                                     'in_reply_to_screen_name': None,
#                                     'in_reply_to_status_id': None,
#                                     'in_reply_to_status_id_str': None,
#                                     'in_reply_to_user_id': None,
#                                     'in_reply_to_user_id_str': None,
#                                     'is_quote_status': False,
#                                     'lang': 'en',
#                                     'metadata': {'iso_language_code': 'en',
#                                                  'result_type': 'recent'},
#                                     'place': None,
#                                     'retweet_count': 4644,
#                                     'retweeted': False,
#                                     'source': '<a '
#                                               'href="http://twitter.com/download/iphone" '
#                                               'rel="nofollow">Twitter for '
#                                               'iPhone</a>',
#                                     'text': 'I’m not a socialist. But I '
#                                             'believe that every American '
#                                             'deserves health care. I also '
#                                             'believe that college should be… '
#                                             'https://t.co/OHxUjzjzHB',
#                                     'truncated': True,
#                                     'user': {'contributors_enabled': False,
#                                              'created_at': 'Tue Jun 16 '
#                                                            '21:54:28 +0000 '
#                                                            '2009',
#                                              'default_profile': False,
#                                              'default_profile_image': False,
#                                              'description': 'United States '
#                                                             'Senator from '
#                                                             'Hawaii. Dad. '
#                                                             'Climate Hawk. '
#                                                             'Appropriator. '
#                                                             'Chief Deputy '
#                                                             'Whip.',
#                                              'entities': {'description': {'urls': []},
#                                                           'url': {'urls': [{'display_url': 'brianschatz.com',
#                                                                             'expanded_url': 'http://www.brianschatz.com',
#                                                                             'indices': [0,
#                                                                                         23],
#                                                                             'url': 'https://t.co/TFoJ19ZTFY'}]}},
#                                              'favourites_count': 4347,
#                                              'follow_request_sent': None,
#                                              'followers_count': 194995,
#                                              'following': None,
#                                              'friends_count': 2085,
#                                              'geo_enabled': True,
#                                              'has_extended_profile': False,
#                                              'id': 47747074,
#                                              'id_str': '47747074',
#                                              'is_translation_enabled': False,
#                                              'is_translator': False,
#                                              'lang': 'en',
#                                              'listed_count': 2304,
#                                              'location': 'ÜT: '
#                                                          '19.72105,-155.087417',
#                                              'name': 'Brian Schatz',
#                                              'notifications': None,
#                                              'profile_background_color': '063482',
#                                              'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif',
#                                              'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif',
#                                              'profile_background_tile': False,
#                                              'profile_banner_url': 'https://pbs.twimg.com/profile_banners/47747074/1504655317',
#                                              'profile_image_url': 'http://pbs.twimg.com/profile_images/840179285440757761/McwUAXF8_normal.jpg',
#                                              'profile_image_url_https': 'https://pbs.twimg.com/profile_images/840179285440757761/McwUAXF8_normal.jpg',
#                                              'profile_link_color': '00B3FF',
#                                              'profile_sidebar_border_color': '1C65DC',
#                                              'profile_sidebar_fill_color': 'EBEBEB',
#                                              'profile_text_color': '1C65DC',
#                                              'profile_use_background_image': True,
#                                              'protected': False,
#                                              'screen_name': 'brianschatz',
#                                              'statuses_count': 10496,
#                                              'time_zone': None,
#                                              'translator_type': 'none',
#                                              'url': 'https://t.co/TFoJ19ZTFY',
#                                              'utc_offset': None,
#                                              'verified': True}},
#                'source': '<a href="http://twitter.com/download/iphone" '
#                          'rel="nofollow">Twitter for iPhone</a>',
#                'text': 'RT @brianschatz: I’m not a socialist. But I believe '
#                        'that every American deserves health care. I also '
#                        'believe that college should be debt fr…',
#                'truncated': False,
#                'user': {'contributors_enabled': False,
#                         'created_at': 'Sun Jun 12 09:41:26 +0000 2016',
#                         'default_profile': False,
#                         'default_profile_image': False,
#                         'description': 'Writer. Critic. Loyal Brother. Just be '
#                                        'kind. It’s that simple ❤️😉 @TheFilmYap',
#                         'entities': {'description': {'urls': []},
#                                      'url': {'urls': [{'display_url': 'thecampuscitizen.com',
#                                                        'expanded_url': 'http://thecampuscitizen.com',
#                                                        'indices': [0, 23],
#                                                        'url': 'https://t.co/ygglvisO4E'}]}},
#                         'favourites_count': 45248,
#                         'follow_request_sent': None,
#                         'followers_count': 150,
#                         'following': None,
#                         'friends_count': 1659,
#                         'geo_enabled': False,
#                         'has_extended_profile': True,
#                         'id': 741928386596118528,
#                         'id_str': '741928386596118528',
#                         'is_translation_enabled': False,
#                         'is_translator': False,
#                         'lang': 'en',
#                         'listed_count': 1,
#                         'location': 'Indianapolis, IN',
#                         'name': 'Manuel Fernandez',
#                         'notifications': None,
#                         'profile_background_color': '000000',
#                         'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                         'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                         'profile_background_tile': False,
#                         'profile_banner_url': 'https://pbs.twimg.com/profile_banners/741928386596118528/1465769228',
#                         'profile_image_url': 'http://pbs.twimg.com/profile_images/980525026293231616/TdrpF4Jq_normal.jpg',
#                         'profile_image_url_https': 'https://pbs.twimg.com/profile_images/980525026293231616/TdrpF4Jq_normal.jpg',
#                         'profile_link_color': '1B95E0',
#                         'profile_sidebar_border_color': '000000',
#                         'profile_sidebar_fill_color': '000000',
#                         'profile_text_color': '000000',
#                         'profile_use_background_image': False,
#                         'protected': False,
#                         'screen_name': 'Secret_Manu',
#                         'statuses_count': 1445,
#                         'time_zone': None,
#                         'translator_type': 'none',
#                         'url': 'https://t.co/ygglvisO4E',
#                         'utc_offset': None,
#                         'verified': False}},
#               {'contributors': None,
#                'coordinates': None,
#                'created_at': 'Sat Feb 09 00:46:50 +0000 2019',
#                'entities': {'hashtags': [],
#                             'symbols': [],
#                             'urls': [],
#                             'user_mentions': [{'id': 960342180282839041,
#                                                'id_str': '960342180282839041',
#                                                'indices': [3, 13],
#                                                'name': 'Elaine Johnson',
#                                                'screen_name': 'ElaineEDO'},
#                                               {'id': 495650403,
#                                                'id_str': '495650403',
#                                                'indices': [100, 109],
#                                                'name': 'Peter Hannam',
#                                                'screen_name': 'p_hannam'}]},
#                'favorite_count': 0,
#                'favorited': False,
#                'geo': None,
#                'id': 1094034857464782848,
#                'id_str': '1094034857464782848',
#                'in_reply_to_screen_name': None,
#                'in_reply_to_status_id': None,
#                'in_reply_to_status_id_str': None,
#                'in_reply_to_user_id': None,
#                'in_reply_to_user_id_str': None,
#                'is_quote_status': False,
#                'lang': 'en',
#                'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#                'place': None,
#                'retweet_count': 63,
#                'retweeted': False,
#                'retweeted_status': {'contributors': None,
#                                     'coordinates': None,
#                                     'created_at': 'Fri Feb 08 10:27:10 +0000 '
#                                                   '2019',
#                                     'entities': {'hashtags': [],
#                                                  'symbols': [],
#                                                  'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                                                            'expanded_url': 'https://twitter.com/i/web/status/1093818515004375041',
#                                                            'indices': [116,
#                                                                        139],
#                                                            'url': 'https://t.co/CAJgiFMAao'}],
#                                                  'user_mentions': [{'id': 495650403,
#                                                                     'id_str': '495650403',
#                                                                     'indices': [85,
#                                                                                 94],
#                                                                     'name': 'Peter '
#                                                                             'Hannam',
#                                                                     'screen_name': 'p_hannam'}]},
#                                     'favorite_count': 100,
#                                     'favorited': False,
#                                     'geo': None,
#                                     'id': 1093818515004375041,
#                                     'id_str': '1093818515004375041',
#                                     'in_reply_to_screen_name': None,
#                                     'in_reply_to_status_id': None,
#                                     'in_reply_to_status_id_str': None,
#                                     'in_reply_to_user_id': None,
#                                     'in_reply_to_user_id_str': None,
#                                     'is_quote_status': False,
#                                     'lang': 'en',
#                                     'metadata': {'iso_language_code': 'en',
#                                                  'result_type': 'recent'},
#                                     'place': None,
#                                     'possibly_sensitive': False,
#                                     'retweet_count': 63,
#                                     'retweeted': False,
#                                     'source': '<a '
#                                               'href="http://twitter.com/download/iphone" '
#                                               'rel="nofollow">Twitter for '
#                                               'iPhone</a>',
#                                     'text': "'Delicious irony': How miner's "
#                                             'challenge became a climate change '
#                                             'win \n'
#                                             '\n'
#                                             'This piece by @p_hannam explains '
#                                             'how a case… '
#                                             'https://t.co/CAJgiFMAao',
#                                     'truncated': True,
#                                     'user': {'contributors_enabled': False,
#                                              'created_at': 'Mon Feb 05 '
#                                                            '02:39:52 +0000 '
#                                                            '2018',
#                                              'default_profile': True,
#                                              'default_profile_image': False,
#                                              'description': 'Principal '
#                                                             'Solicitor '
#                                                             '@EDONSW. Using '
#                                                             'the law to '
#                                                             'protect our Earth '
#                                                             'for future '
#                                                             'generations. On '
#                                                             'leave to mid-2019 '
#                                                             'raising the next '
#                                                             'gen. Acting '
#                                                             'Principal= '
#                                                             '@BrendanEDO',
#                                              'entities': {'description': {'urls': []},
#                                                           'url': {'urls': [{'display_url': 'edonsw.org.au',
#                                                                             'expanded_url': 'http://www.edonsw.org.au',
#                                                                             'indices': [0,
#                                                                                         23],
#                                                                             'url': 'https://t.co/UYzXNVqEGo'}]}},
#                                              'favourites_count': 4512,
#                                              'follow_request_sent': None,
#                                              'followers_count': 1447,
#                                              'following': None,
#                                              'friends_count': 3038,
#                                              'geo_enabled': False,
#                                              'has_extended_profile': False,
#                                              'id': 960342180282839041,
#                                              'id_str': '960342180282839041',
#                                              'is_translation_enabled': False,
#                                              'is_translator': False,
#                                              'lang': 'en',
#                                              'listed_count': 5,
#                                              'location': 'New South Wales, '
#                                                          'Australia',
#                                              'name': 'Elaine Johnson',
#                                              'notifications': None,
#                                              'profile_background_color': 'F5F8FA',
#                                              'profile_background_image_url': None,
#                                              'profile_background_image_url_https': None,
#                                              'profile_background_tile': False,
#                                              'profile_banner_url': 'https://pbs.twimg.com/profile_banners/960342180282839041/1534004017',
#                                              'profile_image_url': 'http://pbs.twimg.com/profile_images/960343777075347456/6CLVRnTo_normal.jpg',
#                                              'profile_image_url_https': 'https://pbs.twimg.com/profile_images/960343777075347456/6CLVRnTo_normal.jpg',
#                                              'profile_link_color': '1DA1F2',
#                                              'profile_sidebar_border_color': 'C0DEED',
#                                              'profile_sidebar_fill_color': 'DDEEF6',
#                                              'profile_text_color': '333333',
#                                              'profile_use_background_image': True,
#                                              'protected': False,
#                                              'screen_name': 'ElaineEDO',
#                                              'statuses_count': 3567,
#                                              'time_zone': None,
#                                              'translator_type': 'none',
#                                              'url': 'https://t.co/UYzXNVqEGo',
#                                              'utc_offset': None,
#                                              'verified': False}},
#                'source': '<a href="http://twitter.com" rel="nofollow">Twitter '
#                          'Web Client</a>',
#                'text': "RT @ElaineEDO: 'Delicious irony': How miner's "
#                        'challenge became a climate change win \n'
#                        '\n'
#                        'This piece by @p_hannam explains how a case originall…',
#                'truncated': False,
#                'user': {'contributors_enabled': False,
#                         'created_at': 'Sat Jun 29 13:41:55 +0000 2013',
#                         'default_profile': False,
#                         'default_profile_image': False,
#                         'description': "don't hide it - provide it",
#                         'entities': {'description': {'urls': []}},
#                         'favourites_count': 120153,
#                         'follow_request_sent': None,
#                         'followers_count': 240,
#                         'following': None,
#                         'friends_count': 1629,
#                         'geo_enabled': False,
#                         'has_extended_profile': False,
#                         'id': 1555704446,
#                         'id_str': '1555704446',
#                         'is_translation_enabled': False,
#                         'is_translator': False,
#                         'lang': 'en-gb',
#                         'listed_count': 0,
#                         'location': '',
#                         'name': 'word saladin',
#                         'notifications': None,
#                         'profile_background_color': 'C0DEED',
#                         'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                         'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                         'profile_background_tile': True,
#                         'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1555704446/1372517493',
#                         'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000063679913/839cb3564f90edccc7df6bc5b3921b52_normal.jpeg',
#                         'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000063679913/839cb3564f90edccc7df6bc5b3921b52_normal.jpeg',
#                         'profile_link_color': '0084B4',
#                         'profile_sidebar_border_color': '000000',
#                         'profile_sidebar_fill_color': 'DDEEF6',
#                         'profile_text_color': '333333',
#                         'profile_use_background_image': True,
#                         'protected': False,
#                         'screen_name': 'EdelweissBlood',
#                         'statuses_count': 14134,
#                         'time_zone': None,
#                         'translator_type': 'none',
#                         'url': None,
#                         'utc_offset': None,
#                         'verified': False}},
#               {'contributors': None,
#                'coordinates': None,
#                'created_at': 'Sat Feb 09 00:46:49 +0000 2019',
#                'entities': {'hashtags': [],
#                             'symbols': [],
#                             'urls': [{'display_url': 'twitter.com/manfromthehand…',
#                                       'expanded_url': 'https://twitter.com/manfromthehand/status/1093641673177997323',
#                                       'indices': [102, 125],
#                                       'url': 'https://t.co/0nIs11zubo'}],
#                             'user_mentions': []},
#                'favorite_count': 0,
#                'favorited': False,
#                'geo': None,
#                'id': 1094034851148099584,
#                'id_str': '1094034851148099584',
#                'in_reply_to_screen_name': None,
#                'in_reply_to_status_id': None,
#                'in_reply_to_status_id_str': None,
#                'in_reply_to_user_id': None,
#                'in_reply_to_user_id_str': None,
#                'is_quote_status': True,
#                'lang': 'en',
#                'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#                'place': {'attributes': {},
#                          'bounding_box': {'coordinates': [[[150.520928608,
#                                                             -34.1183470085],
#                                                            [151.343020992,
#                                                             -34.1183470085],
#                                                            [151.343020992,
#                                                             -33.578140996],
#                                                            [150.520928608,
#                                                             -33.578140996]]],
#                                           'type': 'Polygon'},
#                          'contained_within': [],
#                          'country': 'Australia',
#                          'country_code': 'AU',
#                          'full_name': 'Sydney, New South Wales',
#                          'id': '0073b76548e5984f',
#                          'name': 'Sydney',
#                          'place_type': 'city',
#                          'url': 'https://api.twitter.com/1.1/geo/id/0073b76548e5984f.json'},
#                'possibly_sensitive': False,
#                'quoted_status': {'contributors': None,
#                                  'coordinates': None,
#                                  'created_at': 'Thu Feb 07 22:44:28 +0000 2019',
#                                  'entities': {'hashtags': [],
#                                               'symbols': [],
#                                               'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                                                         'expanded_url': 'https://twitter.com/i/web/status/1093641673177997323',
#                                                         'indices': [117, 140],
#                                                         'url': 'https://t.co/SR0MWWD1MI'}],
#                                               'user_mentions': [{'id': 911359892,
#                                                                  'id_str': '911359892',
#                                                                  'indices': [0,
#                                                                              13],
#                                                                  'name': 'Chaz '
#                                                                          'McSpencer '
#                                                                          'III',
#                                                                  'screen_name': 'i_workout_c3'},
#                                                                 {'id': 1053067568,
#                                                                  'id_str': '1053067568',
#                                                                  'indices': [14,
#                                                                              26],
#                                                                  'name': 'sharon '
#                                                                          'trott',
#                                                                  'screen_name': 'TrottSharon'},
#                                                                 {'id': 15764644,
#                                                                  'id_str': '15764644',
#                                                                  'indices': [27,
#                                                                              41],
#                                                                  'name': 'Nancy '
#                                                                          'Pelosi',
#                                                                  'screen_name': 'SpeakerPelosi'}]},
#                                  'favorite_count': 165,
#                                  'favorited': False,
#                                  'geo': None,
#                                  'id': 1093641673177997323,
#                                  'id_str': '1093641673177997323',
#                                  'in_reply_to_screen_name': 'i_workout_c3',
#                                  'in_reply_to_status_id': 1093588163535212548,
#                                  'in_reply_to_status_id_str': '1093588163535212548',
#                                  'in_reply_to_user_id': 911359892,
#                                  'in_reply_to_user_id_str': '911359892',
#                                  'is_quote_status': False,
#                                  'lang': 'en',
#                                  'metadata': {'iso_language_code': 'en',
#                                               'result_type': 'recent'},
#                                  'place': None,
#                                  'retweet_count': 7,
#                                  'retweeted': False,
#                                  'source': '<a '
#                                            'href="http://twitter.com/download/android" '
#                                            'rel="nofollow">Twitter for '
#                                            'Android</a>',
#                                  'text': '@i_workout_c3 @TrottSharon '
#                                          "@SpeakerPelosi A fetus isn't a baby. "
#                                          'Also, those hit hardest by climate '
#                                          'change will be c… '
#                                          'https://t.co/SR0MWWD1MI',
#                                  'truncated': True,
#                                  'user': {'contributors_enabled': False,
#                                           'created_at': 'Mon Jul 25 01:59:06 '
#                                                         '+0000 2011',
#                                           'default_profile': False,
#                                           'default_profile_image': False,
#                                           'description': 'Nurse. Gamer. Middle '
#                                                          'child. Husband. '
#                                                          'Father. Ice cream '
#                                                          'guy. Critical '
#                                                          'thinker. Pro-juice. '
#                                                          'Mexican octopus.',
#                                           'entities': {'description': {'urls': []}},
#                                           'favourites_count': 79051,
#                                           'follow_request_sent': None,
#                                           'followers_count': 344,
#                                           'following': None,
#                                           'friends_count': 2011,
#                                           'geo_enabled': False,
#                                           'has_extended_profile': False,
#                                           'id': 341845245,
#                                           'id_str': '341845245',
#                                           'is_translation_enabled': False,
#                                           'is_translator': False,
#                                           'lang': 'en',
#                                           'listed_count': 11,
#                                           'location': 'Louisville, KY',
#                                           'name': 'Dan',
#                                           'notifications': None,
#                                           'profile_background_color': '022330',
#                                           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#                                           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#                                           'profile_background_tile': False,
#                                           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/341845245/1509562666',
#                                           'profile_image_url': 'http://pbs.twimg.com/profile_images/1067572654205542400/qwi4Hl0p_normal.jpg',
#                                           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1067572654205542400/qwi4Hl0p_normal.jpg',
#                                           'profile_link_color': '0084B4',
#                                           'profile_sidebar_border_color': 'A8C7F7',
#                                           'profile_sidebar_fill_color': 'C0DFEC',
#                                           'profile_text_color': '333333',
#                                           'profile_use_background_image': True,
#                                           'protected': False,
#                                           'screen_name': 'manfromthehand',
#                                           'statuses_count': 12178,
#                                           'time_zone': None,
#                                           'translator_type': 'none',
#                                           'url': None,
#                                           'utc_offset': None,
#                                           'verified': False}},
#                'quoted_status_id': 1093641673177997323,
#                'quoted_status_id_str': '1093641673177997323',
#                'retweet_count': 0,
#                'retweeted': False,
#                'source': '<a href="http://twitter.com/download/iphone" '
#                          'rel="nofollow">Twitter for iPhone</a>',
#                'text': 'Climate change caused by man is a hoax. What a '
#                        'brainwashed idiot you appear to be, man from the hand. '
#                        'https://t.co/0nIs11zubo',
#                'truncated': False,
#                'user': {'contributors_enabled': False,
#                         'created_at': 'Wed Dec 03 23:02:27 +0000 2008',
#                         'default_profile': True,
#                         'default_profile_image': False,
#                         'description': 'Author, Internet Marketer, social '
#                                        'media and bitcoin investor. Also build '
#                                        'an online presence for anyone -love to '
#                                        'help people. Let me help you. A happy '
#                                        'gay dad',
#                         'entities': {'description': {'urls': []},
#                                      'url': {'urls': [{'display_url': 'liveagoodlife.me',
#                                                        'expanded_url': 'http://liveagoodlife.me',
#                                                        'indices': [0, 23],
#                                                        'url': 'https://t.co/32VdXuN2Dr'}]}},
#                         'favourites_count': 21873,
#                         'follow_request_sent': None,
#                         'followers_count': 1691,
#                         'following': None,
#                         'friends_count': 1851,
#                         'geo_enabled': True,
#                         'has_extended_profile': True,
#                         'id': 17852277,
#                         'id_str': '17852277',
#                         'is_translation_enabled': False,
#                         'is_translator': False,
#                         'lang': 'en',
#                         'listed_count': 45,
#                         'location': '2A Elizabeth Bay rd, Sydney ',
#                         'name': 'Stuart Fish',
#                         'notifications': None,
#                         'profile_background_color': 'C0DEED',
#                         'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                         'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                         'profile_background_tile': False,
#                         'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17852277/1473326009',
#                         'profile_image_url': 'http://pbs.twimg.com/profile_images/385954205/Me_Feb_06_edited-1_normal.jpg',
#                         'profile_image_url_https': 'https://pbs.twimg.com/profile_images/385954205/Me_Feb_06_edited-1_normal.jpg',
#                         'profile_link_color': '1DA1F2',
#                         'profile_sidebar_border_color': 'C0DEED',
#                         'profile_sidebar_fill_color': 'DDEEF6',
#                         'profile_text_color': '333333',
#                         'profile_use_background_image': True,
#                         'protected': False,
#                         'screen_name': 'stufish7',
#                         'statuses_count': 18431,
#                         'time_zone': None,
#                         'translator_type': 'none',
#                         'url': 'https://t.co/32VdXuN2Dr',
#                         'utc_offset': None,
#                         'verified': False}}]}

# %%
for status in json_tweet_data['statuses']:
    print(status['text'] + '\n')
# Out:
# RT @StevenBeschloss: At a time of great challenge, from climate change to gun violence to income equality, what a waste of time dealing w/T…
#
# RT @SenSanders: I am proud to be an original co-sponsor of the Green New Deal proposal. We must address the existential crisis of planetary…
#
# RT @brianschatz: I’m not a socialist. But I believe that every American deserves health care. I also believe that college should be debt fr…
#
# RT @ElaineEDO: 'Delicious irony': How miner's challenge became a climate change win
#
# This piece by @p_hannam explains how a case originall…
#
# Climate change caused by man is a hoax. What a brainwashed idiot you appear to be, man from the hand. https://t.co/0nIs11zubo

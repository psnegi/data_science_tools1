# %% [markdown]
# # Web Scrapping
#
# Extracting webpages and parsing them for in readable format.
#
# Usually it is HTML. We'll use
# - **Requests** to get the webpage
# - **[Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/)** to parse it. It parses HTML and XML with the help of a parser(**html or lxml**)

# %% [markdown]
# <center> <h1> Beautiful Soup  </h1> </center>
#
# From the website
#
# **"You didn't write that awful page. You're just trying to get some data out of it. Beautiful Soup is here to help."**
#
# Install
# - **pip install beautifulsoup4**
# - **pip install lxml**
# in your virtual environment.

# %% [markdown]
# # Protocol to follow when scrapping the web page
# - Check for robot.txt and see what is allowed
# - Avoid lots of simultaneous calls. Your IP may get block. Use sleep between making get call to avoid this.
#
# - Use Requests get method to get the webpage html
# - Parse it using Beautiful Soup and lxml. It creates a hierarchical structure of html elements.
# - In chrome right click and click on inspect to open developer tools. Inspecting the html elements for their attributes and hierarchical order.
# - Use Beautiful Soup object to get to the desired element.

# %% [markdown]
# # An example of parsing html
#
# Visit this [w3schools](https://www.w3schools.com/html/html_basic.asp) to get an idea about HTML

# %%
html_doc = """
<!DOCTYPE html>
<html><head><title>The Dormouse's story</title></head>
<body>

<p class="story_title"><b>The Dormouse's story three little sisters</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
</body>
</html>
"""

# %% [markdown]
# <!DOCTYPE html>
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="story_title"><b>The Dormouse's story three little sisters</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
# <a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
# <a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
#
# <p class="story">...</p>
# </body>
# </html>

# %%
from bs4 import BeautifulSoup as bsoup

# %%
soup = bsoup(html_doc, 'lxml')
print(type(soup))
print(soup)
# Out:
# <class 'bs4.BeautifulSoup'>
# <!DOCTYPE html>
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="story_title"><b>The Dormouse's story three little sisters</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>
# </html>

# %% [markdown]
# # Navigating this data structure

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
soup.title.text
# Out:
# "The Dormouse's story"

# %%
soup.title.string
# Out:
# "The Dormouse's story"

# %%
soup.title.parent
# Out:
# <head><title>The Dormouse's story</title></head>

# %%
# print the name and text in parent tag ??????
soup.title.parent.text
# Out:
# "The Dormouse's story"

# %% [markdown]
# # p tag represent a paragraph of text

# %%
soup.p
# Out:
# <p class="story_title"><b>The Dormouse's story three little sisters</b></p>

# %% [markdown]
# p tag has some attribute too, like class here. How to get the value of attribute

# %%
soup.p['class']
# Out:
# ['story_title']

# %% [markdown]
# But there were more **p** tags. How to get them from soup data structure

# %%
soup.find_all('p')
# Out:
# [<p class="story_title"><b>The Dormouse's story three little sisters</b></p>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <p class="story">...</p>]

# %% [markdown]
# The **a** tag defines a hyperlink, to link  to another webpage
#
# <img src=""> </img>

# %%
# Find all the url(href) in a tags
for atag in soup.find_all('a'):
    print(atag['href'])
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
# Third link
soup.find(id="link3")
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
# complete text
soup.get_text()
# Out:
# "The Dormouse's story\n\nThe Dormouse's story three little sisters\nOnce upon a time there were three little sisters; and their names were\nElsie,\nLacie and\nTillie;\nand they lived at the bottom of a well.\n...\n\n\n"

# %% [markdown]
# # Let's create some Beautiful Soup
#
# We will scrap fry electronics for telescopes following the protocol and store the result in a csv file.

# %% [markdown]
# # Checking robots.txt

# %%
# !curl  https://www.frys.com/robots.txt
# Out:
# User-agent: *
# Crawl-delay: 10
# Sitemap: http://www.frys.com/sitemap_index.xml
# Visit-time: 0030-0300
# Disallow: /ShopCartServlet
# Disallow: /wf

# %%
# import requests and bs4 
from bs4 import BeautifulSoup as bsoup
import requests

# %%
response = requests.get('https://www.frys.com/search?query_search=&cat=-68822&nearbyStoreName=false&pType=pDisplay&fq=a%20Regular%20Items&start=0&cat=-68822&from=0&to=99&isKeyword=true')

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '\r\n\r\n<!-- Desktop page for search. -->\r\n\r\n<HTML>\r\n\t<HEAD>\r\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=Edge">\r\n\t\t<base href="https://www.frys.com/">\r\n\t\t\n<script type="text/javascript">window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var o=n[t]={exports:{}};e[t][0].call(o.exports,function(n){var o=e[t][1][n];return r(o||n)},o,o.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<t.length;o++)r(t[o]);return r}({1:[function(e,n,t){function r(){}function o(e,n,t){return function(){return i(e,[c.now()].concat(u(arguments)),n?null:this,t),n?void 0:this}}var i=e("handle"),a=e(3),u=e(4),f=e("ee").get("tracer"),c=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],d="api-",l=d+"ixn-";a(p,function(e,n){s[n]=o(d+n,!0,"api")}),s.addPageAction=o(d+"addPageAction",!0),s.setCurrentRouteName=o(d+"routeName",!0),n.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,n){var t={},r=this,o="function"==typeof n;return i(l+"tracer",[c.now(),e,t],r),function(){if(f.emit((o?"":"no-")+"fn-start",[c.now(),r,o],t),o)try{return n.apply(this,arguments)}catch(e){throw f.emit("fn-err",[arguments,this,e],t),e}finally{f.emit("fn-end",[c.now()],t)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(e,n){m[n]=o(l+n)}),newrelic.noticeError=function(e,n){"string"==typeof e&&(e=new Error(e)),i("err",[e,c.now(),!1,n])}},{}],2:[function(e,n,t){function r(e,n){if(!o)return!1;if(e!==o)return!1;if(!n)return!0;if(!i)return!1;for(var t=i.split("."),r=n.split("."),a=0;a<r.length;a++)if(r[a]!==t[a])return!1;return!0}var o=null,i=null,a=/Version\\/(\\S+)\\s+Safari/;if(navigator.userAgent){var u=navigator.userAgent,f=u.match(a);f&&u.indexOf("Chrome")===-1&&u.indexOf("Chromium")===-1&&(o="Safari",i=f[1])}n.exports={agent:o,version:i,match:r}},{}],3:[function(e,n,t){function r(e,n){var t=[],r="",i=0;for(r in e)o.call(e,r)&&(t[i]=n(r,e[r]),i+=1);return t}var o=Object.prototype.hasOwnProperty;n.exports=r},{}],4:[function(e,n,t){function r(e,n,t){n||(n=0),"undefined"==typeof t&&(t=e?e.length:0);for(var r=-1,o=t-n||0,i=Array(o<0?0:o);++r<o;)i[r]=e[n+r];return i}n.exports=r},{}],5:[function(e,n,t){n.exports={exists:"undefined"!=typeof window.performance&&window.performance.timing&&"undefined"!=typeof window.performance.timing.navigationStart}},{}],ee:[function(e,n,t){function r(){}function o(e){function n(e){return e&&e instanceof r?e:e?f(e,u,i):i()}function t(t,r,o,i){if(!d.aborted||i){e&&e(t,r,o);for(var a=n(o),u=v(t),f=u.length,c=0;c<f;c++)u[c].apply(a,r);var p=s[y[t]];return p&&p.push([b,t,r,a]),a}}function l(e,n){h[e]=v(e).concat(n)}function m(e,n){var t=h[e];if(t)for(var r=0;r<t.length;r++)t[r]===n&&t.splice(r,1)}function v(e){return h[e]||[]}function g(e){return p[e]=p[e]||o(t)}function w(e,n){c(e,function(e,t){n=n||"feature",y[t]=n,n in s||(s[n]=[])})}var h={},y={},b={on:l,addEventListener:l,removeEventListener:m,emit:t,get:g,listeners:v,context:n,buffer:w,abort:a,aborted:!1};return b}function i(){return new r}function a(){(s.api||s.feature)&&(d.aborted=!0,s=d.backlog={})}var u="nr@context",f=e("gos"),c=e(3),s={},p={},d=n.exports=o();d.backlog=s},{}],gos:[function(e,n,t){function r(e,n,t){if(o.call(e,n))return e[n];var r=t();if(Object.defineProperty&&Object.keys)try{return Object.defineProperty(e,n,{value:r,writable:!0,enumerable:!1}),r}catch(i){}return e[n]=r,r}var o=Object.prototype.hasOwnProperty;n.exports=r},{}],handle:[function(e,n,t){function r(e,n,t,r){o.buffer([e],r),o.emit(e,n,t)}var o=e("ee").get("handle");n.exports=r,r.ee=o},{}],id:[function(e,n,t){function r(e){var n=typeof e;return!e||"object"!==n&&"function"!==n?-1:e===window?0:a(e,i,function(){return o++})}var o=1,i="nr@id",a=e("gos");n.exports=r},{}],loader:[function(e,n,t){functi ...

# %%
soup= bsoup(response.text, 'lxml')

# %%
telescope_containers = soup.find_all('div', {"class":"col-xs-12 col-sm-12 pad_lr_tab5 product togrid"})

# %%
telescope_container = telescope_containers[0]

# %%
def scrap_telescope(telescope_container):
    product_dict= {}
    telescope_info = telescope_container.find('div', {"class":"col-xs-12 col-sm-4 col-md-5 pad_none_tab pad_lr_desk5 toGirdDesc"})

    product_desc_container = telescope_info.find('p')
    product_desc = product_desc_container.text.strip()
    print(product_desc)
    
    product_dict['product_desc']=product_desc
    product_info_container =  telescope_info.find('div', {"class":"col-xs-12 pad_none_tab pad_none_desk prodModel"})

    product_attr_container = product_info_container.find_all('p')

    for product_attr in product_attr_container[:-1]:
        product_val = product_attr.text.strip().split(':')
        product_dict[product_val[0]] = product_val[1]
    return product_dict

# %%
for telescope_container in telescope_containers:
    print(scrap_telescope(telescope_container))
# Out:
# Polaroid Telescope with Interchangeable 75x/150x Eyepiece Lenses
# {'product_desc': 'Polaroid Telescope with Interchangeable 75x/150x Eyepiece Lenses', 'Frys #': ' 9547962', 'Brand': ' Polaroid', 'UPC ': ' 681066491096', 'Model': ' IT-160X'}
# Polaroid 168x/525x Refractor Telescope
# {'product_desc': 'Polaroid 168x/525x Refractor Telescope', 'Frys #': ' 9547922', 'Brand': ' Polaroid', 'UPC ': ' 681066110782', 'Model': ' IT-525X-RFR'}
# CELESTRON KIDS MICROSCPE KIDS MICROSCOPE W/CASE
# {'product_desc': 'CELESTRON KIDS MICROSCPE KIDS MICROSCOPE W/CASE', 'Frys #': ' 8335697', 'Brand': ' Celestron', 'UPC ': ' 050234441230', 'Model': ' KIDS 28 PIECE MICROS'}
# Celestron PowerSeeker 60EQ Refractor Telescope
# {'product_desc': 'Celestron PowerSeeker 60EQ Refractor Telescope', 'Frys #': ' 5536400', 'Brand': ' Celestron', 'UPC ': ' 050234210430', 'Model': ' POWERSEEKER 60EQ'}
# Celestron LandScout 50mm Spotting Scope
# {'product_desc': 'Celestron LandScout 50mm Spotting Scope', 'Frys #': ' 7897269', 'Brand': ' Celestron', 'UPC ': ' 050234523202', 'Model': ' LANDSCOUT 50MM SPOTT'}
# Celestron Kids 50mm Refractor With Case
# {'product_desc': 'Celestron Kids 50mm Refractor With Case', 'Frys #': ' 8335637', 'Brand': ' Celestron', 'UPC ': ' 050234220156', 'Model': ' KIDS 50MM REFRACTOR'}
# Celestron Cometron 7x50 Binoculars
# {'product_desc': 'Celestron Cometron 7x50 Binoculars', 'Frys #': ' 7897289', 'Brand': ' Celestron', 'UPC ': ' 050234711982', 'Model': ' COMETRON 7X50'}
# Celestron Inspire 100AZ 100AZ Refractor Telescpe Fully Coated Glass Optic Smartphone
# {'product_desc': 'Celestron Inspire 100AZ 100AZ Refractor Telescpe Fully Coated Glass Optic Smartphone', 'Frys #': ' 9013827', 'Brand': ' Celestron', 'UPC ': ' 050234224031', 'Model': ' 22403'}
# Celestron Cometron FirstScope 76mm f/4 Alt-Az Reflector Telescope
# {'product_desc': 'Celestron Cometron FirstScope 76mm f/4 Alt-Az Reflector Telescope', 'Frys #': ' 7897249', 'Brand': ' Celestron', 'UPC ': ' 050234210232', 'Model': ' FIRSTSCOPE'}
# Celestron AstroMaster LT 70AZ Telescope
# {'product_desc': 'Celestron AstroMaster LT 70AZ Telescope', 'Frys #': ' 9172588', 'Brand': ' Celestron', 'UPC ': ' 050234210744', 'Model': ' 21074'}
# Celestron Powerskr 114EQ 114mm, 900mm Focal 2eye Pcs, 3X Barlow, EQ Mount Aluminum Tripod
# {'product_desc': 'Celestron Powerskr 114EQ 114mm, 900mm Focal 2eye Pcs, 3X Barlow, EQ Mount Aluminum Tripod', 'Frys #': ' 3935318', 'Brand': ' Celestron', 'UPC ': ' 050234210454', 'Model': ' Powerskr 114EQ'}
# Celestron ExploraScope 80AZ 80mm Refractor Telescope
# {'product_desc': 'Celestron ExploraScope 80AZ 80mm Refractor Telescope', 'Frys #': ' 9172578', 'Brand': ' Celestron', 'UPC ': ' 050234221023', 'Model': ' 22102'}
# Celestron National Park Foundation ExploraScope 60 AZ 60mm Refractor
# {'product_desc': 'Celestron National Park Foundation ExploraScope 60 AZ 60mm Refractor', 'Frys #': ' 8457798', 'Brand': ' Celestron', 'UPC ': ' 050234221054', 'Model': ' 22105'}
# Celestron National Park Foundation TravelScope 60 Telescope Kit
# {'product_desc': 'Celestron National Park Foundation TravelScope 60 Telescope Kit', 'Frys #': ' 8457808', 'Brand': ' Celestron', 'UPC ': ' 050234220057', 'Model': ' 22005'}
# Celestron Cometron 114AZ 114 mm parabolic mirror Fast focal ratio Newtonian Reflector
# {'product_desc': 'Celestron Cometron 114AZ 114 mm parabolic mirror Fast focal ratio Newtonian Reflector', 'Frys #': ' 7897239', 'Brand': ' Celestron', 'UPC ': ' 050234210799', 'Model': ' COMETRON 114AZ'}
# Meade StarPro AZ 70mm Refractor Telescope
# {'product_desc': 'Meade StarPro AZ 70mm Refractor Telescope', 'Frys #': ' 9742974', 'Brand': ' MEADE', 'UPC ': ' 709942999839', 'Model': ' StarPro AZ 70mm Refr'}
# Meade StarPro AZ 102mm Refractor Telescope
# {'product_desc': 'Meade StarPro AZ 102mm Refractor Telescope', 'Frys #': ' 9742964', 'Brand': ' MEADE', 'UPC ': ' 709942999860', 'Model': ' StarPro AZ 102mm Ref'}
# StarNavigator NG 130mm with Carry Bag
# {'product_desc': 'StarNavigator NG 130mm with Carry Bag', 'Frys #': ' 9742984', 'Brand': ' MEADE', 'UPC ': ' 709942998269', 'Model': ' StarNavigator NG 130'}
# Celestron Powerseeker 60AZ Telescope
# {'product_desc': 'Celestron Powerseeker 60AZ Telescope', 'Frys #': ' 5756302', 'Brand': ' Celestron', 'UPC ': ' 050234210416', 'Model': ' POWERSEEKER 60AZ TEL'}
# Celestron AsroFi 90 WiFi Astro 90mm Refractor Wi-Fi Controlled SkyAlign Technology
# {'product_desc': 'Celestron AsroFi 90 WiFi Astro 90mm Refractor Wi-Fi Controlled SkyAlign Technology', 'Frys #': ' 9013817', 'Brand': ' Celestron', 'UPC ': ' 050234222013', 'Model': ' 22201'}

# %% [markdown]
# # Load this notebook to the canvas after completing assigned coding/written response excercises. Question  2 will be graded based on github activity and 1, 3 and 4 based on written response/code in this notebook.

# %% [markdown]
# # Only one team member should complete the activities in this cell
#
# - Create a project repository in the github.com(while creating repository give a appropriate repository name, select private and Initialize this repository with a README )
# - Add all the team members,  instructor (github id: **psnegi**) and GTA(github id: **pilotmitchw**) as collaborator(send an invite to us using collaborator option in the github)
#
# <font color ="red"> Let's know  if you don't want to share your github with us.</font>

# %% [markdown]
# # Q1 (.5 point)  *write your **repository url** here in this notebook.*
#
# **Write url here(Double click to edit this markdown cell.)**
#
# If we click on this url, it should navigate to your repository on the github.

# %% [markdown]
# # Q2(1.5 points) Editing README.md markdown file about your project. content.
#
#  Depending upon number of team members split following work of creating README.md file. Each team member(even if you are working alone)
#  should create a local branch with the name **HW2_your_name_feature_name** and finish the work of editing a section of the README file. Push the  branch to remote too.
#
#  <font color="red">Don't delete the remote branch, we'll review the README contribution in the branch.</font>
#
# In the **README.md add the following  headers** (use # for creating header). Share following 3 work items between team members.
#
# 1.  Team members name and project objective (Describe project objective(1  paragraph should be enough)
# 1. Dataset attribute and metadata (If there are too many *(more than 15)* attribute) , just list some attributes you think are most important/interesting. For each attribute give 2 sample values(normal and a noisy one if it exists)
# 1. Add a tentative timeline  in a tabular format for
#     + data collection(if collecting data)
#     + data cleanup
#     + transformation
#     + feature engineering
#     + statistical summary
#     + visualization
#
#
# Each team member should create a branch and
# should follow the git workflow for working in a team.
#
# *e.g if I agreed on writing objective part in a team working on world_bank_loan_analysis repository/project, my branch will be* **HW2_psnegi_objective**
#
# ## One of the team members should put a tag named HW2_COMPLETED before due date once each team member has done the assigned work. We'll use this tag to check the final  work.

# %% [markdown]
# # Q3 (1= .5+ .5 point) Using python inbuilt *filter* function and *reduce function from functools*, find the product of all the odd numbers in x. Write one line for the solution code.

# %%
import functools 
x = [3, 6, 9, 11, 20]
list(filter(lambda x: x%2 != 0, x))
# Out:
# [3, 9, 11]

# %%
# write your code here

# %% [markdown]
# # Q4(1 point) Some time in data science we need to create a subset of all the possible variables. Given following list of variables, print all the possible subset(tuple) of variables  using itertools *combination* function.
#  Each combination of variables should be printed on a seperate line.
#
#  Hint: some of the sample output lines
#
#  ('x1',)
#
# ('x2',)
#
# ('x3',)
#
# ('x4',)
#
# ('x1', 'x2')
#
# ('x1', 'x3')

# %%
import itertools as itt
variables = ['x'+str(i) for i in range(1, 4 + 1)]
print(variables)
# Out:
# ['x1', 'x2', 'x3', 'x4']

# %%
# Write your code here. You should be done in 3 lines.
